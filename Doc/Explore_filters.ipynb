# %%
import cPickle as pickle
from pprint import pprint
pos_feats, neg_feats = pickle.load(open('filter_feats.pk'))

print 'filter', 0
print '------ positive features'
pprint(pos_feats[0][:20])
print '------ negative features'
pprint(neg_feats[0][:20])
# Out:
# filter 0
# ------ positive features
# [('pos_-1_CC', 0.0075921677),
#  ('suffix_-1_tic', 0.0043584774),
#  ('normal_-1_and', 0.0041224025),
#  ('lemma_-1_and', 0.00374911),
#  ('word_-1_and', 0.0037483322),
#  ('suffix_-1_and', 0.0036162517),
#  ('prefix_-1_and', 0.0035602984),
#  ('pos_1_NN', 0.0033381204),
#  ('pos_2_NN', 0.0033065549),
#  ('word_length_-1_0', 0.0031953645)]
# ------ negative features
# [('pos_1_CC', -0.0034806672),
#  ('word_length_1_0', -0.0034589053),
#  ('pos_2_CC', -0.002889385),
#  ('lemma_-1_decrease', -0.0027854559),
#  ('suffix_-1_ted', -0.0027300452),
#  ('word_length_-2_4', -0.002717712),
#  ('suffix_-1_ine', -0.0025562469),
#  ('prefix_-1_res', -0.0025296237),
#  ('lemma_-1_elevated', -0.0024980179),
#  ('word_length_-1_3', -0.0023581062)]

# %%
for i in range(200):
    print 'filter', i
    print '------ positive features'
    pprint(pos_feats[i][:10])
    print '------ negative features'
    pprint(neg_feats[i][:10])
    print ''
# Out:
# filter 0
# ------ positive features
# [('pos_-1_CC', 0.0075921677),
#  ('suffix_-1_tic', 0.0043584774),
#  ('normal_-1_and', 0.0041224025),
#  ('lemma_-1_and', 0.00374911),
#  ('word_-1_and', 0.0037483322),
#  ('suffix_-1_and', 0.0036162517),
#  ('prefix_-1_and', 0.0035602984),
#  ('pos_1_NN', 0.0033381204),
#  ('pos_2_NN', 0.0033065549),
#  ('word_length_-1_0', 0.0031953645)]
# ------ negative features
# [('pos_1_CC', -0.0034806672),
#  ('word_length_1_0', -0.0034589053),
#  ('pos_2_CC', -0.002889385),
#  ('lemma_-1_decrease', -0.0027854559),
#  ('suffix_-1_ted', -0.0027300452),
#  ('word_length_-2_4', -0.002717712),
#  ('suffix_-1_ine', -0.0025562469),
#  ('prefix_-1_res', -0.0025296237),
#  ('lemma_-1_elevated', -0.0024980179),
#  ('word_length_-1_3', -0.0023581062)]
#
# filter 1
# ------ positive features
# [('word_0_valve', 7.9672078e-05),
#  ('lemma_0_valve', 7.0881018e-05),
#  ('normal_0_valve', 5.2874337e-05),
#  ('word_1_valve', 4.8071284e-05),
#  ('pos_0_VBN', 4.5472185e-05),
#  ('lemma_0_decrease', 4.3363139e-05),
#  ('lemma_1_valve', 4.2764965e-05),
#  ('med_prefix_0_dilat', 3.3553955e-05),
#  ('lemma_0_she', 3.2800526e-05),
#  ('normal_1_valve', 3.1900228e-05)]
# ------ negative features
# [('sentence_pos_0_0', -8.9599584e-05),
#  ('lemma_0_normal', -7.4615877e-05),
#  ('normal_0_normal', -6.7987108e-05),
#  ('word_length_0_5', -6.5638313e-05),
#  ('pos_0_NNS', -5.3869211e-05),
#  ('sentence_pos_1_0', -5.381908e-05),
#  ('word_0_normal', -4.9558676e-05),
#  ('word_length_0_3', -4.7935213e-05),
#  ('sentence_pos_0_5', -4.7795857e-05),
#  ('word_length_0_0', -4.75835e-05)]
#
# filter 2
# ------ positive features
# [('word_length_-1_3', 0.25415379),
#  ('pos_-1_NN', 0.24885429),
#  ('pos_-1_PRP$', 0.16225542),
#  ('pos_-1_VBG', 0.1572538),
#  ('pos_-1_NNS', 0.14708583),
#  ('pos_-1_CD', 0.13734266),
#  ('word_length_2_3', 0.13593893),
#  ('pos_-1_VBD', 0.13555151),
#  ('lemma_0_be', 0.13543107),
#  ('suffix_-1_ine', 0.13392392)]
# ------ negative features
# [('pos_-1_CC', -0.31808886),
#  ('pos_-2_CC', -0.1937685),
#  ('lemma_-1_or', -0.17026567),
#  ('suffix_-1_tic', -0.16772561),
#  ('pos_-1_,', -0.1595376),
#  ('pos_2_CC', -0.15761842),
#  ('normal_-1_or', -0.13526829),
#  ('word_-1_or', -0.13078232),
#  ('lemma_-1_fever', -0.12575203),
#  ('prefix_-1_and', -0.12309268)]
#
# filter 3
# ------ positive features
# [('pos_-2_CC', 0.002593769),
#  ('lemma_-2_or', 0.0025185584),
#  ('word_-2_or', 0.0021961324),
#  ('normal_-2_or', 0.002127026),
#  ('umls_match_tag_full_2_B', 0.0015592981),
#  ('prefix_-2_or', 0.0015486157),
#  ('pos_-1_CC', 0.0015185988),
#  ('suffix_-2_or', 0.0014526878),
#  ('word_-1_valve', 0.0014497659),
#  ('pos_-2_,', 0.0012899272)]
# ------ negative features
# [('pos_1_NN', -0.0020637696),
#  ('sentence_pos_-2_0', -0.0019497542),
#  ('pos_0_JJ', -0.0019394268),
#  ('sentence_pos_-1_0', -0.0018489655),
#  ('word_length_-2_3', -0.0018188187),
#  ('pos_-2_CD', -0.0017517358),
#  ('sentence_pos_0_0', -0.0017423001),
#  ('lemma_1_normal', -0.0017402406),
#  ('pos_2_NNS', -0.0016999878),
#  ('pos_-2_VBD', -0.0015982776)]
#
# filter 4
# ------ positive features
# [('word_length_-1_3', 0.22159843),
#  ('pos_-1_IN', 0.20604415),
#  ('lemma_-1_be', 0.20195881),
#  ('word_length_-1_2', 0.1851798),
#  ('pos_-1_CD', 0.16552572),
#  ('pos_-1_PRP$', 0.15640873),
#  ('word_length_-1_1', 0.15115142),
#  ('lemma_-1_have', 0.14629318),
#  ('word_-1_cavity', 0.14292599),
#  ('lemma_-1_she', 0.1418521)]
# ------ negative features
# [('lemma_-1_fever', -0.17280148),
#  ('lemma_-1_fall', -0.149663),
#  ('normal_-1_afib', -0.14478731),
#  ('pos_0_IN', -0.14168295),
#  ('normal_-1_pain', -0.137494),
#  ('lemma_-1_mass', -0.13191168),
#  ('med_prefix_-1_calci', -0.12915058),
#  ('prefix_-1_SOB', -0.12823671),
#  ('pos_-1_CC', -0.1274284),
#  ('lemma_-1_pain', -0.1272908)]
#
# filter 5
# ------ positive features
# [('word_1_valve', 0.00049197424),
#  ('lemma_1_valve', 0.00043770147),
#  ('word_0_valve', 0.00037943877),
#  ('lemma_0_valve', 0.00033757542),
#  ('normal_1_valve', 0.00032651931),
#  ('pos_1_VBN', 0.00028172386),
#  ('lemma_1_decrease', 0.00026770588),
#  ('normal_0_valve', 0.00025182249),
#  ('word_2_valve', 0.00022202445),
#  ('word_-1_valve', 0.00021775679)]
# ------ negative features
# [('sentence_pos_1_0', -0.00055390364),
#  ('lemma_1_normal', -0.00046051588),
#  ('sentence_pos_0_0', -0.00042730471),
#  ('normal_1_normal', -0.00041981091),
#  ('word_length_1_5', -0.00040581715),
#  ('lemma_0_normal', -0.00035542654),
#  ('pos_1_NNS', -0.00033268347),
#  ('normal_0_normal', -0.00032393291),
#  ('word_length_0_5', -0.00031299554),
#  ('word_1_normal', -0.00030559191)]
#
# filter 6
# ------ positive features
# [('word_0_valve', 5.259446e-06),
#  ('word_1_valve', 4.8973616e-06),
#  ('lemma_0_valve', 4.6792375e-06),
#  ('lemma_1_valve', 4.3570994e-06),
#  ('normal_0_valve', 3.4906504e-06),
#  ('normal_1_valve', 3.250344e-06),
#  ('pos_0_VBN', 3.0124822e-06),
#  ('lemma_0_decrease', 2.861922e-06),
#  ('pos_1_VBN', 2.8050624e-06),
#  ('lemma_1_decrease', 2.6648941e-06)]
# ------ negative features
# [('sentence_pos_0_0', -5.9220802e-06),
#  ('sentence_pos_1_0', -5.5143896e-06),
#  ('lemma_0_normal', -4.9234445e-06),
#  ('lemma_1_normal', -4.5844663e-06),
#  ('normal_0_normal', -4.4882408e-06),
#  ('word_length_0_5', -4.3380974e-06),
#  ('normal_1_normal', -4.1792314e-06),
#  ('word_length_1_5', -4.0395412e-06),
#  ('pos_0_NNS', -3.5571613e-06),
#  ('pos_1_NNS', -3.3122394e-06)]
#
# filter 7
# ------ positive features
# [('word_2_valve', 0.0014801236),
#  ('lemma_2_valve', 0.0013190222),
#  ('word_1_valve', 0.0011551467),
#  ('word_-2_valve', 0.0010651837),
#  ('word_0_valve', 0.0010610134),
#  ('lemma_1_valve', 0.0010423154),
#  ('normal_2_valve', 0.00098916597),
#  ('lemma_0_valve', 0.0009563666),
#  ('lemma_-2_valve', 0.00094957004),
#  ('pos_2_VBN', 0.00090832595)]
# ------ negative features
# [('sentence_pos_2_0', -0.0016586299),
#  ('lemma_2_normal', -0.0013801651),
#  ('sentence_pos_1_0', -0.0012735261),
#  ('normal_2_normal', -0.0012581218),
#  ('word_length_2_5', -0.0012259781),
#  ('sentence_pos_-2_0', -0.0012088071),
#  ('sentence_pos_0_0', -0.0011872586),
#  ('lemma_1_normal', -0.001073804),
#  ('lemma_0_normal', -0.00098268024),
#  ('normal_1_normal', -0.00098069839)]
#
# filter 8
# ------ positive features
# [('pos_0_NN', 0.17314424),
#  ('pos_-1_CD', 0.17131065),
#  ('word_length_-1_0', 0.16499437),
#  ('word_length_-1_2', 0.16279267),
#  ('lemma_-1_be', 0.15198925),
#  ('word_length_-1_4', 0.1500228),
#  ('pos_1_NN', 0.13647318),
#  ('normal_-1_[unk]', 0.13558084),
#  ('sentence_pos_-1_0', 0.13384864),
#  ('word_length_-1_3', 0.12451445)]
# ------ negative features
# [('lemma_-1_fever', -0.13888595),
#  ('normal_-1_afib', -0.1220944),
#  ('lemma_-1_fall', -0.11948103),
#  ('pos_0_IN', -0.1186745),
#  ('umls_match_tag_acro_-1_I ', -0.1136521),
#  ('pos_0_JJ', -0.11325372),
#  ('prefix_-1_SOB', -0.1089178),
#  ('lemma_-1_decrease', -0.1071861),
#  ('suffix_-1_GIB', -0.10498419),
#  ('prefix_-1_dys', -0.10347532)]
#
# filter 9
# ------ positive features
# [('lemma_0_fever', 0.49326029),
#  ('normal_0_afib', 0.43429506),
#  ('lemma_0_fall', 0.42289346),
#  ('lemma_0_mass', 0.42087904),
#  ('med_prefix_0_calci', 0.38750762),
#  ('prefix_0_SOB', 0.38625583),
#  ('suffix_0_GIB', 0.37037635),
#  ('umls_match_tag_full_0_B', 0.36818805),
#  ('prefix_0_dys', 0.36640799),
#  ('umls_match_tag_acro_0_I ', 0.35868999)]
# ------ negative features
# [('word_length_0_0', -0.49212572),
#  ('pos_0_IN', -0.48827231),
#  ('med_prefix_0_sever', -0.44994313),
#  ('word_0_cavity', -0.42849752),
#  ('lemma_0_have', -0.42684686),
#  ('lemma_0_she', -0.41089433),
#  ('lemma_0_patient', -0.36216798),
#  ('lemma_0_be', -0.3588115),
#  ('word_length_0_1', -0.33371189),
#  ('pos_0_CD', -0.32383251)]
#
# filter 10
# ------ positive features
# [('med_prefix_0_sever', 0.35074666),
#  ('lemma_0_she', 0.3232896),
#  ('word_length_0_5', 0.31834573),
#  ('word_length_0_0', 0.31419328),
#  ('word_0_cavity', 0.30016857),
#  ('lemma_0_have', 0.29838631),
#  ('pos_0_DT', 0.267097),
#  ('word_length_0_1', 0.25260523),
#  ('lemma_0_patient', 0.2524547),
#  ('sentence_pos_0_4', 0.24971874)]
# ------ negative features
# [('lemma_0_fever', -0.35639778),
#  ('lemma_0_mass', -0.34039751),
#  ('umls_match_tag_acro_0_I ', -0.31783605),
#  ('lemma_0_fall', -0.31072742),
#  ('normal_0_afib', -0.30223686),
#  ('prefix_0_SOB', -0.26850525),
#  ('umls_match_tag_acro_0_B ', -0.26593217),
#  ('med_prefix_0_calci', -0.2653375),
#  ('suffix_0_GIB', -0.25765198),
#  ('prefix_0_dys', -0.25488159)]
#
# filter 11
# ------ positive features
# [('lemma_0_fever', 0.36249727),
#  ('normal_0_afib', 0.35901666),
#  ('med_prefix_0_calci', 0.33626318),
#  ('prefix_0_SOB', 0.32107198),
#  ('prefix_0_dys', 0.30735576),
#  ('suffix_0_GIB', 0.30474478),
#  ('lemma_0_fall', 0.29712656),
#  ('prefix_0_ARD', 0.28928435),
#  ('lemma_0_mass', 0.28462675),
#  ('prefix_0_diz', 0.2838394)]
# ------ negative features
# [('word_length_0_0', -0.3908222),
#  ('med_prefix_0_sever', -0.38171461),
#  ('word_0_cavity', -0.35894176),
#  ('lemma_0_have', -0.35151014),
#  ('lemma_0_be', -0.31594366),
#  ('pos_0_IN', -0.3134453),
#  ('med_prefix_0_failure', -0.31178087),
#  ('lemma_0_patient', -0.30475536),
#  ('prefix_0_mod', -0.28649381),
#  ('pos_0_CC', -0.26869819)]
#
# filter 12
# ------ positive features
# [('med_prefix_1_malalignment', 5.2429841e-05),
#  ('med_prefix_1_abdominal', 4.5474062e-05),
#  ('med_prefix_1_other', 4.2382686e-05),
#  ('med_prefix_1_psoriasis', 3.6029276e-05),
#  ('med_prefix_1_fracture', 3.3585111e-05),
#  ('med_prefix_1_heart', 3.1900683e-05),
#  ('sentence_length_1_3', 3.172948e-05),
#  ('med_prefix_1_distress', 2.9633631e-05),
#  ('med_prefix_1_negativ', 2.7947506e-05),
#  ('med_prefix_1_symptoms', 2.7793061e-05)]
# ------ negative features
# [('med_prefix_1_diaphore', -4.1119747e-05),
#  ('med_prefix_1_attri', -4.048078e-05),
#  ('med_prefix_1_impaction', -3.6473382e-05),
#  ('med_prefix_1_cardia', -3.5878267e-05),
#  ('word_pos_1_4', -3.5752371e-05),
#  ('pos_1_VBG', -3.498435e-05),
#  ('med_prefix_1_fluid', -3.4660312e-05),
#  ('pos_1_JJR', -3.428389e-05),
#  ('pos_1_VBN', -3.223446e-05),
#  ('med_prefix_1_still', -3.208367e-05)]
#
# filter 13
# ------ positive features
# [('word_pos_0_6', 4.3084322e-07),
#  ('med_prefix_2_duodenum', 3.2134554e-07),
#  ('sentence_length_2_4', 3.1102118e-07),
#  ('word_pos_1_2', 2.9177025e-07),
#  ('pos_2_VBZ', 2.8608733e-07),
#  ('pos_-1_NNP', 2.8274297e-07),
#  ('umls_match_tag_prefix_1_I', 2.7982523e-07),
#  ('sentence_length_1_2', 2.7977936e-07),
#  ('pos_2_RB', 2.7698684e-07),
#  ('sentence_pos_0_2', 2.5591098e-07)]
# ------ negative features
# [('med_prefix_2_passa', -5.5496884e-07),
#  ('sentence_length_0_2', -4.7866212e-07),
#  ('med_prefix_0_passa', -3.7785912e-07),
#  ('pos_1_VBZ', -3.7767757e-07),
#  ('med_prefix_1_icterus', -3.1087862e-07),
#  ('med_prefix_-2_psoriasis', -2.9172116e-07),
#  ('pos_1_-RRB-', -2.9027311e-07),
#  ('med_prefix_0_cervic', -2.847905e-07),
#  ('umls_match_tag_acro_0_B ', -2.7807639e-07),
#  ('med_prefix_2_enlarge', -2.6979143e-07)]
#
# filter 14
# ------ positive features
# [('pos_1_CC', 0.20100941),
#  ('lemma_0_be', 0.1825629),
#  ('lemma_1_or', 0.15447564),
#  ('med_prefix_0_sever', 0.13342448),
#  ('word_1_or', 0.13005149),
#  ('normal_1_or', 0.12429773),
#  ('word_0_cavity', 0.11993223),
#  ('lemma_0_have', 0.11802042),
#  ('word_length_0_2', 0.11485478),
#  ('pos_0_CC', 0.1142749)]
# ------ negative features
# [('word_length_-1_3', -0.16489571),
#  ('pos_-1_CC', -0.15332305),
#  ('umls_match_tag_full_0_B', -0.15023591),
#  ('normal_0_afib', -0.12030419),
#  ('lemma_0_fever', -0.11481387),
#  ('prefix_0_SOB', -0.10757338),
#  ('capitalized_1_0', -0.10675111),
#  ('pos_1_VBD', -0.10596967),
#  ('med_prefix_0_calci', -0.10458078),
#  ('suffix_0_GIB', -0.10238086)]
#
# filter 15
# ------ positive features
# [('word_length_-2_3', 0.00048223211),
#  ('sentence_length_0_1', 0.00035845346),
#  ('pos_0_VBN', 0.00028966463),
#  ('pos_-1_VBN', 0.00025994744),
#  ('sentence_length_-2_1', 0.00025889868),
#  ('lemma_2_be', 0.00025487109),
#  ('sentence_length_-1_1', 0.00023152331),
#  ('sentence_length_1_1', 0.00022846303),
#  ('word_pos_0_4', 0.00022665586),
#  ('sentence_length_2_1', 0.00022660894)]
# ------ negative features
# [('capitalized_0_0', -0.00030507299),
#  ('med_prefix_1__', -0.00028901521),
#  ('pos_-2_DT', -0.00028525904),
#  ('umls_match_tag_prefix_0_I', -0.00028051002),
#  ('lemma_0_right', -0.00025868494),
#  ('pos_2_DT', -0.00025859656),
#  ('sentence_pos_-1_1', -0.00025519295),
#  ('normal_0_right', -0.00025327361),
#  ('word_0_right', -0.00024528956),
#  ('pos_0_,', -0.00023881362)]
#
# filter 16
# ------ positive features
# [('umls_match_tag_full_-2_B', 0.0083188517),
#  ('word_0_valve', 0.0078092888),
#  ('word_1_valve', 0.0069404729),
#  ('lemma_0_valve', 0.0067480183),
#  ('lemma_1_valve', 0.0058610402),
#  ('word_-1_valve', 0.0057585207),
#  ('normal_0_valve', 0.005025201),
#  ('pos_0_CC', 0.0048527652),
#  ('word_2_valve', 0.0048123486),
#  ('lemma_1_decrease', 0.0047640605)]
# ------ negative features
# [('sentence_pos_0_0', -0.0091475975),
#  ('pos_0_NN', -0.0085164569),
#  ('word_length_0_5', -0.0082217446),
#  ('pos_-1_NN', -0.0082155718),
#  ('lemma_0_normal', -0.0080693038),
#  ('sentence_pos_1_0', -0.0074618226),
#  ('sentence_pos_-1_0', -0.0073450692),
#  ('normal_0_normal', -0.0072638905),
#  ('lemma_-1_normal', -0.0071127578),
#  ('pos_0_NNS', -0.0069113644)]
#
# filter 17
# ------ positive features
# [('pos_-1_CC', 4.2679558e-06),
#  ('suffix_-1_tic', 2.9768476e-06),
#  ('normal_-1_and', 2.3418909e-06),
#  ('suffix_-1_and', 2.0917987e-06),
#  ('prefix_-1_and', 2.0666173e-06),
#  ('word_length_-1_0', 2.0556645e-06),
#  ('lemma_-1_and', 1.9136678e-06),
#  ('word_-1_and', 1.8975513e-06),
#  ('lemma_-1_,', 1.5726074e-06),
#  ('word_length_-1_1', 1.5573449e-06)]
# ------ negative features
# [('lemma_-1_decrease', -1.9962617e-06),
#  ('suffix_-1_ted', -1.9162674e-06),
#  ('suffix_-1_ine', -1.8375118e-06),
#  ('lemma_-1_elevated', -1.7116133e-06),
#  ('prefix_-1_res', -1.611729e-06),
#  ('pos_-1_NN', -1.5955351e-06),
#  ('pos_-1_VBN', -1.5483994e-06),
#  ('word_-1_dilated', -1.4124408e-06),
#  ('word_-1_leaflets', -1.373341e-06),
#  ('pos_-1_VBG', -1.2213367e-06)]
#
# filter 18
# ------ positive features
# [('pos_0_-RRB-', 7.2625967e-06),
#  ('pos_0_VBZ', 6.9476891e-06),
#  ('word_pos_0_5', 5.2992887e-06),
#  ('pos_0_PRP', 5.1268703e-06),
#  ('pos_0_VBG', 4.756273e-06),
#  ('word_pos_0_6', 4.1814683e-06),
#  ('med_prefix_-1_passa', 4.118514e-06),
#  ('med_prefix_0_aspiration', 4.0751133e-06),
#  ('word_pos_0_4', 3.9568595e-06),
#  ('med_prefix_-1_cervic', 3.9489455e-06)]
# ------ negative features
# [('umls_match_tag_prefix_0_I', -6.6014832e-06),
#  ('med_prefix_-1__', -4.0961545e-06),
#  ('pos_-1_VB', -4.0433679e-06),
#  ('med_prefix_0_cervic', -4.0041336e-06),
#  ('sentence_length_0_3', -3.8052538e-06),
#  ('pos_0_,', -3.6838787e-06),
#  ('med_prefix_0_distress', -3.5331739e-06),
#  ('sentence_length_0_2', -3.479171e-06),
#  ('med_prefix_0_malalignment', -3.384205e-06),
#  ('med_prefix_0_strong', -3.349742e-06)]
#
# filter 19
# ------ positive features
# [('pos_-1_CC', 0.12983288),
#  ('pos_-1_JJ', 0.10237563),
#  ('pos_1_CC', 0.087395348),
#  ('capitalized_-2_0', 0.08662568),
#  ('pos_-2_NN', 0.081822507),
#  ('umls_match_tag_full_-2_I', 0.079361029),
#  ('normal_-1_and', 0.078235559),
#  ('lemma_-1_or', 0.077998817),
#  ('pos_0_NN', 0.076326139),
#  ('normal_-2_right', 0.075415909)]
# ------ negative features
# [
# ('pos_-1_NN', -0.091849566),
#  ('pos_2_CC', -0.085144833),
#  ('pos_0_IN', -0.065308958),
#  ('lemma_2_be', -0.065180525),
#  ('word_length_-2_3', -0.063539773),
#  ('word_length_1_1', -0.059685752),
#  ('pos_1_NN', -0.059102155),
#  ('word_length_2_1', -0.058932099),
#  ('pos_-2_IN', -0.055698499),
#  ('pos_0_VBN', -0.055698294)]
#
# filter 20
# ------ positive features
# [('umls_match_tag_full_0_B', 0.11416207),
#  ('pos_1_CC', 0.10912724),
#  ('word_length_1_0', 0.087125644),
#  ('pos_0_NN', 0.08598616),
#  ('pos_-2_CC', 0.077291504),
#  ('capitalized_2_1', 0.070977025),
#  ('lemma_0_fever', 0.069903791),
#  ('normal_0_afib', 0.0630069),
#  ('lemma_0_fall', 0.060168315),
#  ('lemma_2_or', 0.059204917)]
# ------ negative features
# [('word_length_0_0', -0.10177812),
#  ('pos_0_CC', -0.09890341),
#  ('med_prefix_0_sever', -0.088050537),
#  ('capitalized_2_0', -0.079384878),
#  ('pos_-2_JJ', -0.078688659),
#  ('pos_0_DT', -0.078300625),
#  ('word_length_-1_4', -0.07430131),
#  ('pos_0_IN', -0.070565432),
#  ('word_length_1_4', -0.0686455),
#  ('word_length_-2_2', -0.066763163)]
#
# filter 21
# ------ positive features
# [('word_length_-1_3', 0.11204292),
#  ('umls_match_tag_full_0_B', 0.055581611),
#  ('word_length_-2_1', 0.055064235),
#  ('pos_-2_IN', 0.053440858),
#  ('word_length_-2_5', 0.049852815),
#  ('pos_-1_PRP$', 0.046973765),
#  ('sentence_pos_-2_1', 0.046467144),
#  ('pos_-1_IN', 0.045752853),
#  ('pos_-2_VBD', 0.044371445),
#  ('capitalized_2_1', 0.042660855)]
# ------ negative features
# [('pos_0_CC', -0.064174563),
#  ('umls_match_tag_prefix_-2_I', -0.054877806),
#  ('pos_-2_JJ', -0.05482088),
#  ('capitalized_2_0', -0.049983449),
#  ('word_length_0_0', -0.046907201),
#  ('pos_-2_NN', -0.043677565),
#  ('pos_2_,', -0.042865843),
#  ('lemma_-1_right', -0.041875672),
#  ('suffix_-1_tic', -0.04164784),
#  ('umls_match_tag_full_-1_I', -0.041611288)]
#
# filter 22
# ------ positive features
# [('pos_-1_JJ', 0.23725319),
#  ('word_length_1_3', 0.20848234),
#  ('umls_match_tag_full_0_I', 0.18226863),
#  ('pos_0_NN', 0.17049874),
#  ('pos_1_NNS', 0.15952663),
#  ('pos_1_NN', 0.15295467),
#  ('word_length_-1_3', 0.14798005),
#  ('pos_2_CC', 0.13768393),
#  ('pos_1_VB', 0.12029137),
#  ('word_length_0_2', 0.12022725)]
# ------ negative features
# [('pos_-2_CC', -0.15717803),
#  ('pos_0_CC', -0.11666017),
#  ('pos_1_,', -0.10034902),
#  ('med_prefix_1_infer', -0.093814529),
#  ('capitalized_1_0', -0.093776532),
#  ('umls_match_tag_full_0_O', -0.087974861),
#  ('prefix_0_wit', -0.086966552),
#  ('umls_match_tag_full_2_I', -0.086182386),
#  ('pos_1_-RRB-', -0.082986251),
#  ('word_length_2_4', -0.081661269)]
#
# filter 23
# ------ positive features
# [('med_prefix_1_presyncope', 1.5760562e-06),
#  ('med_prefix_1_cervic', 1.4529123e-06),
#  ('word_pos_1_6', 1.0574294e-06),
#  ('med_prefix_1_aorti', 9.6301721e-07),
#  ('med_prefix_1_heart', 9.5206315e-07),
#  ('med_prefix_1_fluid', 9.4325435e-07),
#  ('pos_1_:', 9.3136418e-07),
#  ('word_pos_1_7', 9.2604762e-07),
#  ('umls_match_tag_full_1_I', 9.1920322e-07),
#  ('med_prefix_1_posturing', 9.1463119e-07)]
# ------ negative features
# [('pos_1_RB', -1.6497104e-06),
#  ('med_prefix_1_arrythmia', -1.440078e-06),
#  ('pos_1_-RRB-', -1.289471e-06),
#  ('med_prefix_1_icterus', -1.2163614e-06),
#  ('med_prefix_1_attri', -1.1977186e-06),
#  ('sentence_pos_1_3', -1.0941744e-06),
#  ('med_prefix_1_constipation', -1.0391266e-06),
#  ('sentence_pos_1__unk_', -8.8344854e-07),
#  ('med_prefix_1_dementia', -8.7983091e-07),
#  ('med_prefix_1_report', -8.6504815e-07)]
#
# filter 24
# ------ positive features
# [('pos_-2_-RRB-', 0.0024455437),
#  ('pos_-1_-RRB-', 0.0023662187),
#  ('med_prefix_-1_posturing', 0.0021533323),
#  ('med_prefix_-1_presyncope', 0.0021230797),
#  ('pos_-1_VBZ', 0.0020981787),
#  ('med_prefix_-2_presyncope', 0.002064087),
#  ('med_prefix_-2_posturing', 0.0020488335),
#  ('pos_-1_VBG', 0.0020446666),
#  ('pos_1_-RRB-', 0.0020440463),
#  ('pos_0_-RRB-', 0.0020343016)]
# ------ negative features
# [('umls_match_tag_prefix_-2_I', -0.002790089),
#  ('umls_match_tag_full_-1_B', -0.0027555665),
#  ('umls_match_tag_prefix_-1_I', -0.0027321912),
#  ('word_length_2_3', -0.0025727667),
#  ('umls_match_tag_full_0_B', -0.0023643677),
#  ('med_prefix_-1_malalignment', -0.0023395948),
#  ('med_prefix_-1_other', -0.0022793734),
#  ('umls_match_tag_full_-2_B', -0.0022776292),
#  ('pos_1_IN', -0.0019325482),
#  ('med_prefix_-2_malalignment', -0.001780736)]
#
# filter 25
# ------ positive features
# [('word_pos_-1_6', 4.11146e-07),
#  ('med_prefix_-1_posturing', 3.8758299e-07),
#  ('med_prefix_-1_psoriasis', 3.2991139e-07),
#  ('med_prefix_-1_nodules', 3.2801833e-07),
#  ('med_prefix_-1_dorsal', 3.2412603e-07),
#  ('pos_-1_PRP', 3.2154813e-07),
#  ('med_prefix_-1_presyncope', 3.1893248e-07),
#  ('med_prefix_-1_cortic', 3.0245243e-07),
#  ('med_prefix_-1_obesity', 2.9980635e-07),
#  ('med_prefix_1_enlarge', 2.9861187e-07)]
# ------ negative features
# [('umls_match_tag_prefix_-1_I', -4.7296871e-07),
#  ('sentence_pos_2_0', -4.460488e-07),
#  ('med_prefix_1_arrythmia', -4.1437525e-07),
#  ('word_length_2_5', -3.9309543e-07),
#  ('pos_1_VBD', -3.7347581e-07),
#  ('sentence_pos_2_2', -3.5987887e-07),
#  ('med_prefix_-1_constipation', -3.2393183e-07),
#  ('word_length_2_3', -2.9296126e-07),
#  ('word_length_2_0', -2.8899564e-07),
#  ('umls_match_tag_acro_-1_O ', -2.8712535e-07)]
#
# filter 26
# ------ positive features
# [('med_prefix_-1__', 0.21043009),
#  ('word_length_-1_0', 0.14567499),
#  ('word_length_0_5', 0.14045653),
#  ('umls_match_tag_full_-1_O', 0.13893691),
#  ('umls_match_tag_full_-2_O', 0.11276758),
#  ('pos_-1_IN', 0.11023131),
#  ('capitalized_2_0', 0.10813742),
#  ('pos_-1_DT', 0.10570033),
#  ('pos_-1_CC', 0.10569678),
#  ('prefix_0_res', 0.10455539)]
# ------ negative features
# [('umls_match_tag_full_-1_B', -0.274932),
#  ('word_length_-1_3', -0.18338235),
#  ('pos_0_,', -0.16627795),
#  ('pos_-1_NN', -0.15734352),
#  ('pos_0_CC', -0.12491883),
#  ('lemma_0_dilate', -0.11597056),
#  ('normal_0_ca', -0.11407862),
#  ('umls_match_tag_acro_-1_O ', -0.11159024),
#  ('normal_0_vessel', -0.10937758),
#  ('umls_match_tag_full_-1_I', -0.10730331)]
#
# filter 27
# ------ positive features
# [('umls_match_tag_acro_2_O ', 3.0679752e-05),
#  ('umls_match_tag_prefix_2_B', 2.7777676e-05),
#  ('sentence_length_2_2', 2.6792115e-05),
#  ('med_prefix_2_impaction', 2.4788122e-05),
#  ('umls_match_tag_acro_2_B ', 2.257393e-05),
#  ('umls_match_tag_prefix_2_O', 2.1704534e-05),
#  ('pos_2_CC', 2.1297865e-05),
#  ('med_prefix_2_klebsiella', 1.9892581e-05),
#  ('pos_2_DT', 1.7037131e-05),
#  ('umls_match_tag_prefix_2_I', 1.6626056e-05)]
# ------ negative features
# [('word_pos_2_6', -3.6145637e-05),
#  ('med_prefix_2_presyncope', -3.3080934e-05),
#  ('word_pos_2_9', -3.1762756e-05),
#  ('sentence_pos_2_2', -2.7224676e-05),
#  ('sentence_pos_2_5', -2.264684e-05),
#  ('med_prefix_2_cortic', -2.2160248e-05),
#  ('med_prefix_2_other', -2.2077567e-05),
#  ('med_prefix_2_obesity', -2.0690173e-05),
#  ('word_length_2_1', -2.0192902e-05),
#  ('word_length_2_4', -1.9924073e-05)]
#
# filter 28
# ------ positive features
# [('pos_0_NN', 0.32708311),
#  ('word_length_-1_0', 0.28906423),
#  ('med_prefix_-1_sever', 0.24292125),
#  ('umls_match_tag_full_0_I', 0.24261022),
#  ('word_length_-1_2', 0.24228363),
#  ('word_-1_cavity', 0.23819135),
#  ('lemma_-1_have', 0.23764989),
#  ('capitalized_0_0', 0.23293231),
#  ('pos_-1_IN', 0.23223016),
#  ('lemma_-1_she', 0.23132744)]
# ------ negative features
# [('pos_0_CC', -0.3729614),
#  ('umls_match_tag_full_-1_B', -0.29324377),
#  ('lemma_-1_fever', -0.28143206),
#  ('lemma_-1_fall', -0.24358135),
#  ('normal_-1_afib', -0.24226218),
#  ('lemma_-1_mass', -0.21911958),
#  ('prefix_-1_SOB', -0.21552031),
#  ('med_prefix_-1_calci', -0.21226349),
#  ('suffix_-1_GIB', -0.20977297),
#  ('umls_match_tag_acro_-1_I ', -0.2055591)]
#
# filter 29
# ------ positive features
# [('umls_match_tag_full_-2_B', 0.20696028),
#  ('lemma_0_fever', 0.20584784),
#  ('normal_0_afib', 0.19066657),
#  ('med_prefix_0_calci', 0.18284033),
#  ('lemma_0_fall', 0.17104474),
#  ('prefix_0_SOB', 0.1700165),
#  ('umls_match_tag_acro_-1_I ', 0.1650196),
#  ('suffix_0_GIB', 0.16319546),
#  ('umls_match_tag_full_-1_B', 0.1626806),
#  ('prefix_0_dys', 0.16097462)]
# ------ negative features
# [('word_length_0_3', -0.2419648),
#  ('pos_0_IN', -0.21418545),
#  ('word_length_-1_2', -0.21250457),
#  ('pos_-1_NNS', -0.19726299),
#  ('pos_-1_NN', -0.19716825),
#  ('lemma_0_have', -0.19315968),
#  ('pos_-1_IN', -0.19122986),
#  ('word_length_-1_0', -0.18898113),
#  ('word_0_cavity', -0.18742685),
#  ('word_length_-2_2', -0.18474713)]
#
# filter 30
# ------ positive features
# [('pos_0_IN', 0.43051788),
#  ('pos_-1_CC', 0.35303032),
#  ('med_prefix_0_sever', 0.31678757),
#  ('word_0_cavity', 0.30003381),
#  ('lemma_0_have', 0.29893678),
#  ('lemma_0_she', 0.2673164),
#  ('word_length_0_1', 0.2556994),
#  ('lemma_0_patient', 0.25455061),
#  ('word_length_0_0', 0.23724265),
#  ('word_length_0_5', 0.23587096)]
# ------ negative features
# [('lemma_0_fever', -0.33874977),
#  ('pos_1_CC', -0.30354869),
#  ('normal_0_afib', -0.30057111),
#  ('lemma_0_mass', -0.29575199),
#  ('umls_match_tag_full_-1_B', -0.29232082),
#  ('lemma_0_fall', -0.2855086),
#  ('med_prefix_0_calci', -0.27295715),
#  ('prefix_0_SOB', -0.2680952),
#  ('umls_match_tag_acro_0_B ', -0.26750019),
#  ('prefix_0_dys', -0.2567578)]
#
# filter 31
# ------ positive features
# [('word_length_-1_2', 0.0011900957),
#  ('pos_2_VBN', 0.0010479785),
#  ('pos_-1_VBN', 0.0010338424),
#  ('pos_1_CC', 0.0010286348),
#  ('pos_1_VBN', 0.00080288609),
#  ('umls_match_tag_full_-2_B', 0.0007595463),
#  ('lemma_-1_or', 0.00075768295),
#  ('lemma_1_or', 0.00075670268),
#  ('pos_0_VBN', 0.00074835797),
#  ('word_-1_or', 0.00071529142)]
# ------ negative features
# [('word_length_0_3', -0.0010861591),
#  ('sentence_length_1_2', -0.0010853371),
#  ('pos_0_NN', -0.0010574716),
#  ('sentence_pos_-1_1', -0.00097036874),
#  ('pos_1_NNS', -0.00093606883),
#  ('sentence_length_2_2', -0.00093175558),
#  ('pos_0_NNS', -0.00089454843),
#  ('pos_1_NN', -0.00085235463),
#  ('sentence_length_0_2', -0.00083951023),
#  ('sentence_length_-1_2', -0.00075890112)]
#
# filter 32
# ------ positive features
# [('word_length_0_0', 0.22339888),
#  ('word_0_cavity', 0.21550991),
#  ('lemma_0_have', 0.21494511),
#  ('med_prefix_0_sever', 0.21101655),
#  ('word_length_0_2', 0.20578158),
#  ('pos_0_CC', 0.19358259),
#  ('med_prefix_0_failure', 0.19090016),
#  ('lemma_0_patient', 0.18045577),
#  ('word_length_-1_2', 0.17680363),
#  ('lemma_0_she', 0.16772224)]
# ------ negative features
# [('umls_match_tag_full_0_B', -0.27761739),
#  ('lemma_0_fever', -0.22832917),
#  ('normal_0_afib', -0.22091347),
#  ('prefix_0_SOB', -0.19754943),
#  ('med_prefix_0_calci', -0.19313617),
#  ('suffix_0_GIB', -0.19094059),
#  ('lemma_0_fall', -0.19054712),
#  ('normal_0_pain', -0.18715373),
#  ('prefix_0_dys', -0.18612005),
#  ('prefix_0_ARD', -0.17897746)]
#
# filter 33
# ------ positive features
# [('med_prefix_2_other', 2.2776729e-05),
#  ('med_prefix_-2_ventricul', 2.1547281e-05),
#  ('word_pos_0_6', 2.0685808e-05),
#  ('med_prefix_-2_cervic', 1.8944262e-05),
#  ('med_prefix_-2_posturing', 1.8490133e-05),
#  ('med_prefix_2_cervic', 1.7673186e-05),
#  ('med_prefix_2_abdominal', 1.7149347e-05),
#  ('med_prefix_-2_presyncope', 1.6542595e-05),
#  ('word_pos_2_9', 1.6451972e-05),
#  ('umls_match_tag_acro_2_O ', 1.5034766e-05)]
# ------ negative features
# [('word_pos_2_4', -2.083162e-05),
#  ('sentence_pos_2_5', -1.9379982e-05),
#  ('pos_2_JJR', -1.8722389e-05),
#  ('med_prefix_2_cardia', -1.7661463e-05),
#  ('med_prefix_2_still', -1.7198006e-05),
#  ('word_pos_-2_3', -1.697729e-05),
#  ('med_prefix_2_diaphore', -1.693748e-05),
#  ('pos_2_-RRB-', -1.6316981e-05),
#  ('med_prefix_2_fluid', -1.5781074e-05),
#  ('med_prefix_0_arrythmia', -1.5361082e-05)]
#
# filter 34
# ------ positive features
# [('word_1_valve', 0.00073992054),
#  ('lemma_1_valve', 0.00065811811),
#  ('word_-1_valve', 0.00060345163),
#  ('word_0_valve', 0.000566417),
#  ('lemma_-1_valve', 0.00053636217),
#  ('word_-2_valve', 0.00053261145),
#  ('lemma_0_valve', 0.00050329912),
#  ('normal_1_valve', 0.00049092498),
#  ('lemma_-2_valve', 0.00047246841),
#  ('word_2_valve', 0.00043125043)]
# ------ negative features
# [('sentence_pos_1_0', -0.00083354145),
#  ('lemma_1_normal', -0.0006929792),
#  ('sentence_pos_-1_0', -0.0006800851),
#  ('sentence_pos_0_0', -0.00063934969),
#  ('normal_1_normal', -0.00063166942),
#  ('word_length_1_5', -0.00061082683),
#  ('sentence_pos_-2_0', -0.00060258718),
#  ('lemma_-1_normal', -0.0005655546),
#  ('lemma_0_normal', -0.00053278205),
#  ('normal_-1_normal', -0.00051556597)]
#
# filter 35
# ------ positive features
# [('lemma_-1_fever', 0.36749557),
#  ('normal_-1_afib', 0.32235104),
#  ('lemma_-1_fall', 0.31309995),
#  ('med_prefix_-1_calci', 0.28972936),
#  ('prefix_-1_SOB', 0.28664351),
#  ('lemma_-1_mass', 0.28538263),
#  ('suffix_-1_GIB', 0.27934667),
#  ('prefix_-1_dys', 0.27083522),
#  ('normal_-1_htn', 0.26212651),
#  ('prefix_-1_ARD', 0.26063141)]
# ------ negative features
# [('pos_-1_IN', -0.38473609),
#  ('word_length_-1_3', -0.32070023),
#  ('lemma_-1_have', -0.31967616),
#  ('word_-1_cavity', -0.31495032),
#  ('lemma_-1_she', -0.3099153),
#  ('word_length_-1_4', -0.30059299),
#  ('med_prefix_-1_sever', -0.28549296),
#  ('word_length_-1_2', -0.28066766),
#  ('pos_-1_CD', -0.27180687),
#  ('word_length_-1_0', -0.27153367)]
#
# filter 36
# ------ positive features
# [('word_length_0_0', 0.2437648),
#  ('pos_0_CC', 0.20964824),
#  ('med_prefix_0_sever', 0.20269963),
#  ('lemma_0_be', 0.19189341),
#  ('word_0_cavity', 0.16342337),
#  ('lemma_0_have', 0.15850873),
#  ('prefix_0_mod', 0.14029218),
#  ('pos_0_IN', 0.13741855),
#  ('pos_0_-RRB-', 0.13719803),
#  ('lemma_0_patient', 0.13642536)]
# ------ negative features
# [('pos_0_JJ', -0.16383237),
#  ('lemma_0_fever', -0.1630614),
#  ('normal_0_afib', -0.15914746),
#  ('med_prefix_0_calci', -0.1460281),
#  ('prefix_0_SOB', -0.14230002),
#  ('umls_match_tag_full_0_I', -0.14201149),
#  ('pos_0_NNS', -0.14193049),
#  ('suffix_0_lic', -0.14170617),
#  ('lemma_0_mass', -0.14053832),
#  ('prefix_0_dys', -0.13786881)]
#
# filter 37
# ------ positive features
# [('pos_-1_CC', 0.15301335),
#  ('pos_0_CC', 0.15012619),
#  ('pos_1_NN', 0.10792841),
#  ('umls_match_tag_full_-2_O', 0.10577329),
#  ('word_length_0_0', 0.10311096),
#  ('lemma_-1_or', 0.095774256),
#  ('pos_-1_JJ', 0.087535046),
#  ('normal_-1_or', 0.07914222),
#  ('word_-1_or', 0.077570908),
#  ('pos_1_JJ', 0.076060742)]
# ------ negative features
# [('pos_1_CC', -0.13868727),
#  ('pos_-1_NN', -0.11291649),
#  ('umls_match_tag_full_-2_B', -0.11285331),
#  ('word_length_-1_3', -0.10487596),
#  ('pos_-1_NNS', -0.085860051),
#  ('umls_match_tag_full_0_B', -0.081586473),
#  ('pos_-2_IN', -0.071538493),
#  ('suffix_-2_lic', -0.061222829),
#  ('lemma_0_decrease', -0.060229488),
#  ('pos_-1_PRP$', -0.057054494)]
#
# filter 38
# ------ positive features
# [('word_1_valve', 0.00011957691),
#  ('lemma_1_valve', 0.00010636269),
#  ('word_0_valve', 0.00010251806),
#  ('word_2_valve', 9.2228256e-05),
#  ('lemma_0_valve', 9.1204289e-05),
#  ('lemma_2_valve', 8.2054074e-05),
#  ('normal_1_valve', 7.9321828e-05),
#  ('pos_1_VBN', 6.8781745e-05),
#  ('normal_0_valve', 6.80093e-05),
#  ('lemma_1_decrease', 6.5115979e-05)]
# ------ negative features
# [('sentence_pos_1_0', -0.00013465059),
#  ('sentence_pos_0_0', -0.00011549446),
#  ('lemma_1_normal', -0.00011191962),
#  ('sentence_pos_2_0', -0.00010350565),
#  ('normal_1_normal', -0.00010203034),
#  ('word_length_1_5', -9.8283032e-05),
#  ('lemma_0_normal', -9.6005824e-05),
#  ('normal_0_normal', -8.7530556e-05),
#  ('lemma_2_normal', -8.6190717e-05),
#  ('word_length_0_5', -8.4764666e-05)]
#
# filter 39
# ------ positive features
# [('word_length_0_2', 0.1374203),
#  ('med_prefix_0_sever', 0.13521215),
#  ('pos_0_DT', 0.12350461),
#  ('lemma_0_have', 0.11989143),
#  ('word_0_cavity', 0.11814606),
#  ('lemma_0_she', 0.11780684),
#  ('pos_0_JJ', 0.10786262),
#  ('lemma_0_be', 0.10475372),
#  ('lemma_0_patient', 0.10171965),
#  ('med_prefix_0_failure', 0.099714883)]
# ------ negative features
# [('umls_match_tag_full_0_B', -0.1448357),
#  ('pos_-2_CC', -0.13915378),
#  ('lemma_0_fever', -0.13347527),
#  ('normal_0_afib', -0.11900734),
#  ('med_prefix_0_calci', -0.11515931),
#  ('lemma_0_fall', -0.11295565),
#  ('prefix_0_SOB', -0.10585783),
#  ('suffix_0_GIB', -0.10269871),
#  ('prefix_0_dys', -0.10114677),
#  ('sentence_pos_0__unk_', -0.098720208)]
#
# filter 40
# ------ positive features
# [('umls_match_tag_full_2_B', 0.008525732),
#  ('word_length_0_2', 0.0075699626),
#  ('pos_0_VBN', 0.0075205523),
#  ('pos_-2_VBN', 0.007519823),
#  ('pos_1_VBN', 0.007364301),
#  ('pos_2_RB', 0.0073140678),
#  ('capitalized_0_1', 0.0071082585),
#  ('pos_-1_VBN', 0.0068203672),
#  ('sentence_length_2_1'
# , 0.0067805494),
#  ('word_length_0_1', 0.006662766)]
# ------ negative features
# [('capitalized_0_0', -0.010269484),
#  ('pos_2_DT', -0.0099984994),
#  ('umls_match_tag_prefix_0_I', -0.0087384311),
#  ('pos_-2_DT', -0.0081215687),
#  ('pos_1_,', -0.0079719359),
#  ('capitalized_-2_0', -0.0077684904),
#  ('pos_-1_DT', -0.0077343327),
#  ('umls_match_tag_prefix_1_I', -0.0075339689),
#  ('capitalized_-1_0', -0.0072713192),
#  ('pos_0_,', -0.0072579533)]
#
# filter 41
# ------ positive features
# [('pos_-1_JJ', 0.021600109),
#  ('pos_0_JJ', 0.018834699),
#  ('pos_-2_JJ', 0.01630207),
#  ('lemma_-1_or', 0.014201024),
#  ('pos_-1_CC', 0.014198593),
#  ('capitalized_-1_1', 0.013550603),
#  ('pos_1_CC', 0.013205436),
#  ('word_-1_or', 0.012184569),
#  ('pos_-2_IN', 0.011797937),
#  ('normal_-1_or', 0.01159481)]
# ------ negative features
# [('pos_-2_NN', -0.017724728),
#  ('pos_-1_NN', -0.017246839),
#  ('lemma_-1_be', -0.014460152),
#  ('capitalized_-1_0', -0.012722937),
#  ('lemma_0_be', -0.012594164),
#  ('pos_0_NN', -0.012116426),
#  ('word_length_0_3', -0.011853114),
#  ('pos_-1_VBZ', -0.011549778),
#  ('word_length_2_2', -0.011397504),
#  ('pos_-1_VBG', -0.01066959)]
#
# filter 42
# ------ positive features
# [('med_prefix_0_impaction', 5.3280182e-06),
#  ('sentence_length_0_4', 3.8338467e-06),
#  ('umls_match_tag_full_0_I', 3.0751385e-06),
#  ('umls_match_tag_prefix_0_I', 3.0604351e-06),
#  ('pos_-2_PRP', 2.6135212e-06),
#  ('med_prefix_0_symme', 2.5939978e-06),
#  ('med_prefix_0_arter', 2.5693055e-06),
#  ('pos_-2_RB', 2.5662175e-06),
#  ('pos_0_VB', 2.5036791e-06),
#  ('pos_-2_VBP', 2.3962791e-06)]
# ------ negative features
# [('pos_0_PRP', -5.8913133e-06),
#  ('pos_0_VBG', -5.0157619e-06),
#  ('med_prefix_0_strong', -4.3706004e-06),
#  ('med_prefix_0_passa', -4.1874596e-06),
#  ('pos_0_POS', -4.0960331e-06),
#  ('med_prefix_0_other', -3.7783013e-06),
#  ('med_prefix_0_still', -3.6783858e-06),
#  ('pos_0_VBP', -3.535336e-06),
#  ('med_prefix_0_psoriasis', -3.3816641e-06),
#  ('med_prefix_0_struc', -3.2420583e-06)]
#
# filter 43
# ------ positive features
# [('word_1_valve', 0.00020733351),
#  ('word_2_valve', 0.00020291728),
#  ('lemma_1_valve', 0.00018434248),
#  ('lemma_2_valve', 0.00017837925),
#  ('word_0_valve', 0.00014573123),
#  ('word_-1_valve', 0.00014183154),
#  ('normal_1_valve', 0.00013747916),
#  ('normal_2_valve', 0.00013289404),
#  ('lemma_0_valve', 0.00012961797),
#  ('lemma_-1_valve', 0.00012615506)]
# ------ negative features
# [('sentence_pos_1_0', -0.00023384589),
#  ('sentence_pos_2_0', -0.00023237093),
#  ('lemma_1_normal', -0.00019585942),
#  ('lemma_2_normal', -0.00019042876),
#  ('normal_1_normal', -0.00017797561),
#  ('normal_2_normal', -0.00017416713),
#  ('word_length_2_5', -0.00017298988),
#  ('word_length_1_5', -0.00017097103),
#  ('sentence_pos_0_0', -0.0001642432),
#  ('sentence_pos_-1_0', -0.00015982035)]
#
# filter 44
# ------ positive features
# [('word_1_valve', 3.1160525e-07),
#  ('lemma_1_valve', 2.7497686e-07),
#  ('word_0_valve', 2.4850647e-07),
#  ('pos_1_VBN', 2.343383e-07),
#  ('pos_0_VBN', 2.3196419e-07),
#  ('lemma_0_valve', 2.1973732e-07),
#  ('pos_1_-RRB-', 2.1639194e-07),
#  ('normal_1_valve', 2.0735081e-07),
#  ('pos_-1_NNP', 2.0467692e-07),
#  ('lemma_1_decrease', 1.6715185e-07)]
# ------ negative features
# [('sentence_pos_1_0', -3.4712073e-07),
#  ('sentence_pos_0_0', -2.9535056e-07),
#  ('lemma_1_normal', -2.7430184e-07),
#  ('normal_1_normal', -2.5962885e-07),
#  ('word_length_0_5', -2.3156477e-07),
#  ('lemma_0_normal', -2.2768457e-07),
#  ('word_length_1_5', -2.1330925e-07),
#  ('word_length_1_0', -2.07523e-07),
#  ('umls_match_tag_prefix_1_I', -2.0616606e-07),
#  ('normal_0_normal', -1.9842135e-07)]
#
# filter 45
# ------ positive features
# [('pos_0_NN', 0.13100263),
#  ('pos_1_CC', 0.11331912),
#  ('umls_match_tag_full_0_I', 0.10852096),
#  ('word_length_1_0', 0.10403953),
#  ('umls_match_tag_full_0_B', 0.090505138),
#  ('word_length_-1_3', 0.086316854),
#  ('capitalized_0_0', 0.079889111),
#  ('pos_0_NNS', 0.077584416),
#  ('sentence_pos_2_0', 0.07086055),
#  ('sentence_pos_-1_0', 0.069976687)]
# ------ negative features
# [('pos_0_CC', -0.19849239),
#  ('word_length_0_0', -0.098600298),
#  ('lemma_0_or', -0.083406776),
#  ('pos_2_NN', -0.081005521),
#  ('capitalized_2_0', -0.072094835),
#  ('normal_0_and', -0.067146607),
#  ('lemma_1_decrease', -0.06637682),
#  ('suffix_0_and', -0.064361647),
#  ('word_0_or', -0.063862383),
#  ('word_2_valve', -0.060282078)]
#
# filter 46
# ------ positive features
# [('med_prefix_1_diaphore', 0.0001598068),
#  ('word_length_2_4', 0.0001187875),
#  ('med_prefix_2_aorti', 0.00011370998),
#  ('umls_match_tag_full_1_I', 0.00010533939),
#  ('med_prefix_-1_fluid', 0.00010277151),
#  ('med_prefix_-1_still', 0.00010097644),
#  ('sentence_length_-1_2', 9.3218907e-05),
#  ('med_prefix_-1_decubitus', 9.0101908e-05),
#  ('med_prefix_-1_cardia', 8.9245972e-05),
#  ('umls_match_tag_full_2_B', 8.3600433e-05)]
# ------ negative features
# [('med_prefix_1_arrythmia', -0.00015031101),
#  ('sentence_length_1_2', -0.00011159751),
#  ('med_prefix_-1_malalignment', -0.00010928097),
#  ('umls_match_tag_prefix_2_O', -0.00010545118),
#  ('med_prefix_-1_abdominal', -0.00010521206),
#  ('med_prefix_2_icterus', -9.9327692e-05),
#  ('med_prefix_1_dorsal', -9.2841154e-05),
#  ('med_prefix_1_malalignment', -9.09882e-05),
#  ('med_prefix_1_strong', -8.9858186e-05),
#  ('med_prefix_1_pneumonia', -8.977887e-05)]
#
# filter 47
# ------ positive features
# [('lemma_0_fever', 0.18389778),
#  ('normal_0_afib', 0.18297005),
#  ('pos_1_,', 0.17825364),
#  ('med_prefix_0_calci', 0.17002037),
#  ('prefix_0_SOB', 0.16356419),
#  ('suffix_0_GIB', 0.15747374),
#  ('prefix_0_dys', 0.1549274),
#  ('normal_0_pain', 0.15317406),
#  ('prefix_0_ARD', 0.15041344),
#  ('umls_match_tag_full_0_B', 0.14996788)]
# ------ negative features
# [('word_length_0_2', -0.37607047),
#  ('pos_0_JJ', -0.22440399),
#  ('pos_0_CD', -0.19233754),
#  ('lemma_0_be', -0.1840207),
#  ('lemma_0_have', -0.183403),
#  ('word_0_cavity', -0.17855072),
#  ('pos_-2_NN', -0.16790941),
#  ('word_length_1_5', -0.16523942),
#  ('word_length_0_1', -0.16238074),
#  ('word_length_-1_5', -0.16196078)]
#
# filter 48
# ------ positive features
# [('word_2_valve', 0.0012828412),
#  ('pos_-1_CC', 0.0012577015),
#  ('lemma_2_valve', 0.001141538),
#  ('word_1_valve', 0.00085934071),
#  ('normal_2_valve', 0.00085224322),
#  ('lemma_1_valve', 0.00076148217),
#  ('suffix_-1_tic', 0.0007533789),
#  ('pos_2_VBN', 0.00072235038),
#  ('lemma_2_decrease', 0.0006845225),
#  ('word_-1_valve', 0.00060931244)]
# ------ negative features
# [('sentence_pos_2_0', -0.0014481419),
#  ('lemma_2_normal', -0.0012006867),
#  ('normal_2_normal', -0.0010941428),
#  ('word_length_2_5', -0.0010633277),
#  ('sentence_pos_1_0', -0.00097734702),
#  ('pos_-1_NN', -0.00088792527),
#  ('pos_2_NNS', -0.00087502628),
#  ('lemma_1_normal', -0.00081621),
#  ('word_2_normal', -0.0007968116),
#  ('word_length_-1_5', -0.00077878009)]
#
# filter 49
# ------ positive features
# [('pos_0_IN', 0.092670701),
#  ('lemma_0_she', 0.082038112),
#  ('med_prefix_0_sever', 0.074389756),
#  ('pos_0_DT', 0.073885269),
#  ('word_length_-2_5', 0.071587659),
#  ('pos_-2_NNS', 0.07109642),
#  ('lemma_0_have', 0.06866885),
#  ('word_length_-2_3', 0.06814906),
#  ('med_prefix_0_other', 0.066362128),
#  ('word_0_cavity', 0.066014007)]
# ------ negative features
# [('pos_-1_JJ', -0.12743302),
#  ('word_length_-1_2', -0.093352616),
#  ('umls_match_tag_full_0_B', -0.085698068),
#  ('lemma_0_fever', -0.084931307),
#  ('pos_1_NN', -0.081404582),
#  ('pos_-1_VBN', -0.079608999),
#  ('umls_match_tag_acro_0_O ', -0.07954178),
#  ('pos_-2_CC', -0.079243608),
#  ('lemma_0_mass', -0.077102214),
#  ('lemma_0_fall', -0.075069182)]
#
# filter 50
# ------ positive features
# [('umls_match_tag_prefix_-1_I', 3.3567799e-06),
#  ('med_prefix_-1_malalignment', 3.325719e-06),
#  ('sentence_length_-1_4', 2.9649075e-06),
#  ('med_prefix_-1_other', 2.9284904e-06),
#  ('med_prefix_-1_sacral', 2.9210582e-06),
#  ('med_prefix_-1_fracture', 2.7358922e-06),
#  ('umls_match_tag_prefix_-1_O', 2.7083515e-06),
#  ('med_prefix_-1_bleeding', 2.704671e-06),
#  ('med_prefix_-1_symptoms', 2.7011845e-06),
#  ('med_prefix_-1_accident', 2.6703051e-06)]
# ------ negative features
# [('pos_-1_PRP', -3.6030451e-06),
#  ('pos_-1_VBG', -3.5712915e-06),
#  ('pos_-1_-RRB-', -3.2927767e-06),
#  ('med_prefix_-1_posturing', -3.1997324e-06),
#  ('med_prefix_-1_obesity', -3.0057936e-06),
#  ('med_prefix_-1_fluid', -3.000092e-06),
#  ('med_prefix_-1_presyncope', -2.978554e-06),
#  ('med_prefix_-1_diaphore', -2.8838228e-06),
#  ('med_prefix_-1_syncop', -2.8173179e-06),
#  ('word_pos_-1_4', -2.7688293e-06)]
#
# filter 51
# ------ positive features
# [('pos_-1_RB', 7.2878269e-05),
#  ('med_prefix_-1_psoriasis', 6.9737689e-05),
#  ('med_prefix_-1_malalignment', 6.1639446e-05),
#  ('med_prefix_-1_posturing', 6.1440471e-05),
#  ('med_prefix_-1_hemothorax', 5.4492255e-05),
#  ('med_prefix_2_constipation', 5.3007218e-05),
#  ('med_prefix_-1_abdominal', 5.188871e-05),
#  ('pos_2_VBD', 5.1812822e-05),
#  ('umls_match_tag_prefix_-1_O', 4.7714875e-05),
#  ('umls_match_tag_full_2_B', 4.5987152e-05)]
# ------ negative features
# [('umls_match_tag_full_-1_I', -8.4666877e-05),
#  ('med_prefix_-1_cardia', -7.2713687e-05),
#  ('word_pos_2_7', -7.1099857e-05),
#  ('pos_-1_JJ', -7.0580674e-05),
#  ('pos_-1_NNS', -6.9640322e-05),
#  ('capitalized_2_1', -6.8553229e-05),
#  ('med_prefix_2_posturing', -6.3922067e-05),
#  ('med_prefix_2_impaction', -6.2867912e-05),
#  ('pos_2_JJ', -6.0615763e-05),
#  ('word_pos_-1_4', -5.9344409e-05)]
#
# filter 52
# ------ positive features
# [('word_length_2_3', 0.0013450761),
#  ('pos_0_CC', 0.00086702465),
#  ('word_length_-2_3', 0.00079162605),
#  ('pos_-1_IN', 0.00078797323),
#  ('pos_1_CC', 0.00075608084),
#  ('sentence_length_2_1', 0.00073953508),
#  ('word_pos_-1_5', 0.00073673081),
#  ('umls_match_tag_full_2_B', 0.00069582823),
#  ('umls_match_tag_full_0_O', 0.0006841647),
#  ('pos_2_VB', 0.00064334995)]
# ------ negative features
# [('pos_2_JJ', -0.0017963282),
#  ('word_length_0_5', -0.0013487578),
#  ('word_length_2_2', -0.0012035189),
#  ('umls_match_tag_full_0_B', -0.0011908438),
#  ('lemma_2_right', -0.00099739921),
#  ('normal_2_right', -0.00097006292),
#  ('umls_match_tag_prefix_-1_I', -0.00096505653),
#  ('pos_1_NN', -0.00095836172),
#  ('word_2_right', -0.00094629353),
#  ('word_length_1_4', -0.00087608251)]
#
# filter 53
# ------ positive features
# [('umls_match_tag_prefix_2_I', 3.9637449e-08),
#  ('med_prefix_2_malalignment', 3.5233093e-08),
#  ('med_prefix_0_posturing', 3.3117104e-08),
#  ('med_prefix_-1_arrythmia', 3.1698757e-08),
#  ('med_prefix_1_ventricul', 3.04079e-08),
#  ('sentence_length_1_2', 3.0273593e-08),
#  ('sentence_pos_2_1', 3.0033171e-08),
#  ('med_prefix_0_passa', 2.9493373e-08),
#  ('med_prefix_0_presyncope', 2.9233101e-08),
#  ('med_prefix_1_impaired', 2.8811899e-08)]
# ------ negative features
# [('med_prefix_2_presyncope', -4.3193758e-08),
#  ('med_prefix_2_arrythmia', -3.3354183e-08),
#  ('pos_2_VBG', -3.2514436e-08),
#  ('med_prefix_2_dorsal', -3.1382896e-08),
#  ('word_pos_1_8', -2.9911774e-08),
#  ('med_prefix_2_posturing', -2.963996e-08),
#  ('pos_2_:', -2.9626543e-08),
#  ('med_prefix_2_fluid', -2.8333764e-08),
#  ('capitalized_0_1', -2.8181669e-08),
#  ('med_prefix_1_other', -2.7353687e-08)]
#
# filter 54
# ------ positive features
# [('word_length_0_5', 0.16684681),
#  ('word_length_1_1', 0.15889676),
#  ('med_prefix_-1__', 0.15676296),
#  ('pos_0_VBN', 0.13255982),
#  ('word_length_0_2', 0.12813586),
#  ('pos_0_DT', 0.12495585),
#  ('pos_1_IN', 0.11852097),
#  ('umls_match_tag_prefix_-2_I', 0.11287793),
#  ('word_pos_0_3', 0.1127218),
#  ('word_length_-2_5', 0.10876641)]
# ------ negative features
# [('word_length_-2_1', -0.25886229),
#  ('pos_-1_JJ', -0.23334697),
#  ('capitalized_2_1', -0.19771536),
#  ('word_length_-2_2', -0.18992275),
#  ('word_length_2_2', -0.18531479),
#  ('lemma_-2_be', -0.17789365),
#  ('word_length_-1_1', -0.16832688),
#  ('normal_-1_[unk]', -0.12949573),
#  ('pos_0_,', -0.12930818),
#  ('pos_-2_CC', -0.12526895)]
#
# filter 55
# ------ positive features
# [('umls_match_tag_full_-1_B', 0.22888376),
#  ('lemma_-1_fever', 0.17727558),
#  ('umls_match_tag_acro_-1_O ', 0.16389889),
#  ('normal_-1_afib', 0.15646997),
#  ('lemma_-1_fall', 0.15072045),
#  ('normal_-1_pain', 0.14402278),
#  ('med_prefix_-1_calci', 0.13965137),
#  ('prefix_-1_SOB', 0.13945822),
#  ('lemma_-1_mass', 0.13901332),
#  ('suffix_-1_GIB', 0.13671164)]
# ------ negative features
# [('pos_-1_IN', -0.1938687),
#  ('word_length_-1_2', -0.18834308),
#  ('pos_0_,', -0.18381208),
#  ('med_prefix_-1__', -0.17070454),
#  ('word_length_-1_0', -0.16097051),
#  ('lemma_-1_have', -0.15602112),
#  ('lemma_-1_she', -0.15357646),
#  ('word_-1_cavity', -0.1529966),
#  ('med_prefix_-1_sever', -0.14876409),
#  ('pos_-1_DT', -0.14429863)]
#
# filter 56
# ------ positive features
# [('med_prefix_2_aorti', 2.5845495e-06),
#  ('pos_2_VBD', 2.4741648e-06),
#  ('med_prefix_2_malalignment', 2.4147041e-06),
#  ('med_prefix_2_other', 2.310491e-06),
#  ('med_prefix_2_sacral', 2.2656186e-06),
#  ('med_prefix_2_strong', 1.9765448e-06),
#  ('med_prefix_2_arrythmia', 1.9405279e-06),
#  ('med_prefix_2_constipation', 1.6719418e-06),
#  ('med_prefix_2_thrombi', 1.5904466e-06),
#  ('med_prefix_2_depressed', 1.5597689e-06)]
# ------ negative features
# [('pos_2_-RRB-', -3.5895971e-06),
#  ('pos_2_VBZ', -3.0916906e-06),
#  ('med_prefix_2_posturing', -2.461743e-06),
#  ('med_prefix_2_obesity', -2.3273403e-06),
#  ('med_prefix_2_impaction', -2.2841277e-06),
#  ('med_prefix_2_impaired', -2.1355588e-06),
#  ('med_prefix_2_presyncope', -2.1333346e-06),
#  ('med_prefix_2_syncop', -2.0573341e-06),
#  ('med_prefix_2_icterus', -1.9369413e-06),
#  ('pos_2_VB', -1.8995858e-06)]
#
# filter 57
# ------ positive features
# [('word_1_valve', 0.00044977642),
#  ('lemma_1_valve', 0.00039988474),
#  ('word_-1_valve', 0.00030624852),
#  ('word_0_valve', 0.00030107822),
#  ('normal_1_valve', 0.00029821898),
#  ('word_-2_valve', 0.00029224603),
#  ('lemma_-1_valve', 0.00027230399),
#  ('lemma_0_valve', 0.00026837154),
#  ('lemma_-2_valve', 0.00026109879),
#  ('pos_1_VBN', 0.00025797932)]
# ------ negative features
# [('sentence_pos_1_0', -0.00050816091),
#  ('lemma_1_normal', -0.00042660476),
#  ('normal_1_normal', -0.00038750228),
#  ('word_length_1_5', -0.00036956862),
#  ('sentence_pos_-1_0', -0.0003421921),
#  ('sentence_pos_0_0', -0.00033397527),
#  ('sentence_pos_-2_0', -0.00032530856),
#  ('pos_1_NNS', -0.00030864117),
#  ('lemma_0_normal', -0.00029881488),
#  ('lemma_-1_normal', -0.00029132384)]
#
# filter 58
# ------ positive features
# [('med_prefix_-2_posturing', 2.7896683e-06),
#  ('med_prefix_2_impaction', 2.786194e-06),
#  ('word_pos_-2_9', 2.7191384e-06),
#  ('med_prefix_-2_bradycardi', 2.6643165e-06),
#  ('med_prefix_-2_obesity', 2.6477812e-06),
#  ('med_prefix_-2_impaction', 2.6410817e-06),
#  ('med_prefix_-2_psoriasis', 2.5279301e-06),
#  ('med_prefix_-2_presyncope', 2.5263955e-06),
#  ('med_prefix_-2_diaphore', 2.4805088e-06),
#  ('med_prefix_-2_icterus', 2.4678677e-06)]
# ------ negative features
# [('med_prefix_-2_fracture', -3.0557565e-06),
#  ('pos_2_PRP', -2.8524391e-06),
#  ('word_pos_2_6', -2.8157672e-06),
#  ('pos_-2_VBD', -2.6579305e-06),
#  ('pos_2_VBP', -2.5752677e-06),
#  ('med_prefix_-2_malalignment', -2.5453546e-06),
#  ('med_prefix_2_electro', -2.501931e-06),
#  ('med_prefix_-2_other', -2.4452836e-06),
#  ('sentence_length_-2_2', -2.4003516e-06),
#  ('med_prefix_2_presyncope', -2.3553944e-06)]
#
# filter 59
# ------ positive features
# [('pos_2_JJ', 0.088449933),
#  ('umls_match_tag_full_2_B', 0.082352698),
#  ('pos_-1_JJ', 0.069026649),
#  ('capitalized_0_1', 0.063747145),
#  ('pos_0_NNS', 0.059068568),
#  ('umls_match_tag_full_-2_O', 0.047785431),
#  ('umls_match_tag_full_-1_B', 0.045759849),
#  ('pos_-2_JJ', 0.04568702),
#  ('sentence_pos_1_0', 0.045245018),
#  ('pos_2_CD', 0.044120349)]
# ------ negative features
# [('pos_0_CC', -0.083985031),
#  ('umls_match_tag_full_2_O', -0.057276826),
#  ('word_length_-2_1', -0.057201732),
#  ('umls_match_tag_full_-2_B', -0.055579286),
#  ('word_length_0_0', -0.052428257),
#  ('pos_-1_,', -0.044104226),
#  ('umls_match_tag_full_-1_O', -0.043565322),
#  ('sentence_pos_-2_3', -0.040940076),
#  ('lemma_-2_be', -0.037931092),
#  ('word_-2_:', -0.036791943)]
#
# filter 60
# ------ positive features
# [('pos_0_-RRB-', 6.9518325e-07),
#  ('med_prefix_-2_constipation', 6.881088e-07),
#  ('umls_match_tag_prefix_-2_I', 5.9630406e-07),
#  ('med_prefix_0_sever', 5.7510903e-07),
#  ('sentence_length_-2_2', 5.688359e-07),
#  ('med_prefix_-2_malalignment', 5.6753481e-07),
#  ('word_0_valve', 5.4229491e-07),
#  ('pos_0_CC', 5.348798e-07),
#  ('lemma_0_valve', 5.2804023e-07),
#  ('med_prefix_-2_sacral', 5.2330688e-07)]
# ------ negative features
# [('med_prefix_-2_posturing', -8.18751e-07),
#  ('pos_-2_VBZ', -8.0244166e-07),
#  ('pos_-2_VBG', -7.6592534e-07),
#  ('med_prefix_-2_presyncope', -7.4843655e-07),
#  ('word_length_-2_5', -7.4457677e-07),
#  ('sentence_pos_1_0', -7.4273038e-07),
#  ('sentence_pos_0_0', -6.7377829e-07),
#  ('med_prefix_-2_obesity', -6.4911455e-07),
#  ('word_length_1_5', -6.1501993e-07),
#  ('med_prefix_-2_icterus', -6.0935429e-07)]
#
# filter 61
# ------ positive features
# [('word_2_valve', 2.084338e-08),
#  ('lemma_2_valve', 1.8544004e-08),
#  ('word_-2_valve', 1.8432955e-08),
#  ('word_1_valve', 1.7676241e-08),
#  ('lemma_-2_valve', 1.639949e-08),
#  ('word_0_valve', 1.6359024e-08),
#  ('lemma_1_valve', 1.5726233e-08),
#  ('lemma_0_valve', 1.4554375e-08),
#  ('normal_2_valve', 1.3833575e-08),
#  ('normal_-2_valve', 1.2233797e-08)]
# ------ negative features
# [('sentence_pos_2_0', -2.3469491e-08),
#  ('sentence_pos_-2_0', -2.0755371e-08),
#  ('sentence_pos_1_0', -1.990335e-08),
#  ('lemma_2_normal', -1.951171e-08),
#  ('sentence_pos_0_0', -1.8420701e-08),
#  ('normal_2_normal', -1.7787013e-08),
# ...
#  ('pos_-2_NNP', -7.289397e-05),
#  ('med_prefix_-2_obesity', -6.8338195e-05),
#  ('word_length_-2_5', -6.5988344e-05)]
#
# filter 180
# ------ positive features
# [('word_2_valve', 7.7789961e-09),
#  ('word_1_valve', 7.3694677e-09),
#  ('lemma_2_valve', 6.9208412e-09),
#  ('lemma_1_valve', 6.5564909e-09),
#  ('normal_2_valve', 5.1628537e-09),
#  ('normal_1_valve', 4.8910533e-09),
#  ('pos_2_VBN', 4.4556092e-09),
#  ('lemma_2_decrease', 4.2329247e-09),
#  ('pos_1_VBN', 4.2210431e-09),
#  ('lemma_1_decrease', 4.0100812e-09)]
# ------ negative features
# [('sentence_pos_2_0', -8.7590912e-09),
#  ('sentence_pos_1_0', -8.2979659e-09),
#  ('lemma_2_normal', -7.2820003e-09),
#  ('lemma_1_normal', -6.8986368e-09),
#  ('normal_2_normal', -6.6383237e-09),
#  ('word_length_2_5', -6.4163421e-09),
#  ('normal_1_normal', -6.2888463e-09),
#  ('word_length_1_5', -6.0785501e-09),
#  ('pos_2_NNS', -5.2611866e-09),
#  ('pos_1_NNS', -4.9842086e-09)]
#
# filter 181
# ------ positive features
# [('lemma_-1_fever', 0.14045075),
#  ('normal_-1_afib', 0.12725897),
#  ('med_prefix_-1_calci', 0.12038255),
#  ('lemma_-1_fall', 0.11810755),
#  ('prefix_-1_SOB', 0.11326914),
#  ('suffix_-1_GIB', 0.11023925),
#  ('prefix_-1_dys', 0.10723219),
#  ('umls_match_tag_full_-1_B', 0.10698161),
#  ('prefix_-1_ARD', 0.1045073),
#  ('sentence_pos_-1__unk_', 0.10243894)]
# ------ negative features
# [('pos_-1_IN', -0.15478951),
#  ('lemma_-1_have', -0.12674049),
#  ('word_-1_cavity', -0.12513107),
#  ('word_length_-1_3', -0.12128227),
#  ('word_length_-1_4', -0.1178318),
#  ('lemma_-1_she', -0.11604849),
#  ('med_prefix_-1_sever', -0.11470852),
#  ('word_length_-1_0', -0.11331788),
#  ('med_prefix_-1_failure', -0.11085718),
#  ('lemma_-1_be', -0.11073555)]
#
# filter 182
# ------ positive features
# [('umls_match_tag_full_1_B', 0.23842177),
#  ('lemma_0_fever', 0.22316481),
#  ('normal_0_afib', 0.21430473),
#  ('med_prefix_0_calci', 0.20565355),
#  ('prefix_0_SOB', 0.19136357),
#  ('lemma_0_fall', 0.18493524),
#  ('suffix_0_GIB', 0.18354045),
#  ('prefix_0_dys', 0.18201633),
#  ('umls_match_tag_full_0_B', 0.17412311),
#  ('prefix_0_ARD', 0.17407392)]
# ------ negative features
# [('med_prefix_0_sever', -0.22576155),
#  ('lemma_0_have', -0.21407448),
#  ('word_0_cavity', -0.21067664),
#  ('med_prefix_0_failure', -0.19240129),
#  ('pos_0_IN', -0.1889706),
#  ('word_length_1_3', -0.18747556),
#  ('word_length_1_2', -0.18192035),
#  ('lemma_0_patient', -0.1814366),
#  ('word_length_0_3', -0.17163043),
#  ('lemma_0_she', -0.16788843)]
#
# filter 183
# ------ positive features
# [('word_1_valve', 0.00011497051),
#  ('lemma_1_valve', 0.00010228731),
#  ('word_0_valve', 8.86423e-05),
#  ('lemma_0_valve', 7.8863137e-05),
#  ('normal_1_valve', 7.6304925e-05),
#  ('word_2_valve', 7.229497e-05),
#  ('pos_1_VBN', 6.5851789e-05),
#  ('lemma_2_valve', 6.4329499e-05),
#  ('lemma_1_decrease', 6.2561034e-05),
#  ('normal_0_valve', 5.8830039e-05)]
# ------ negative features
# [('sentence_pos_1_0', -0.00012945615),
#  ('lemma_1_normal', -0.0001076258),
#  ('sentence_pos_0_0', -9.9816432e-05),
#  ('normal_1_normal', -9.8112221e-05),
#  ('word_length_1_5', -9.4830881e-05),
#  ('lemma_0_normal', -8.3010033e-05),
#  ('sentence_pos_2_0', -8.1373022e-05),
#  ('pos_1_NNS', -7.7759025e-05),
#  ('normal_0_normal', -7.5662138e-05),
#  ('word_length_0_5', -7.310712e-05)]
#
# filter 184
# ------ positive features
# [('med_prefix_1_cervic', 5.7080968e-07),
#  ('med_prefix_1_strong', 5.4131232e-07),
#  ('med_prefix_1_malalignment', 5.3115485e-07),
#  ('sentence_length_1_2', 4.7830628e-07),
#  ('med_prefix_1_fracture', 4.6309944e-07),
#  ('med_prefix_1_hypertrophy', 4.484734e-07),
#  ('word_pos_-2_7', 4.0841763e-07),
#  ('med_prefix_1_aorti', 3.7551979e-07),
#  ('pos_-1_VBZ', 3.7276743e-07),
#  ('med_prefix_1_other', 3.5986073e-07)]
# ------ negative features
# [('med_prefix_1_diaphore', -5.2845525e-07),
#  ('med_prefix_1_impaction', -5.0258672e-07),
#  ('med_prefix_1_bradycardi', -3.9903856e-07),
#  ('pos_1_VBN', -3.9264879e-07),
#  ('med_prefix_-1_other', -3.8718323e-07),
#  ('pos_1_VB', -3.8454934e-07),
#  ('med_prefix_1_posturing', -3.7757576e-07),
#  ('med_prefix_1_presyncope', -3.7294734e-07),
#  ('pos_1_-RRB-', -3.7161323e-07),
#  ('med_prefix_1_obesity', -3.4229197e-07)]
#
# filter 185
# ------ positive features
# [('lemma_0_fever', 0.24515109),
#  ('normal_0_afib', 0.23011394),
#  ('med_prefix_0_calci', 0.21353096),
#  ('prefix_0_SOB', 0.20527951),
#  ('lemma_0_fall', 0.20188601),
#  ('suffix_0_GIB', 0.19794692),
#  ('prefix_0_dys', 0.19551662),
#  ('prefix_0_ARD', 0.18845198),
#  ('lemma_0_lesion', 0.18357709),
#  ('normal_0_htn', 0.18227725)]
# ------ negative features
# [('lemma_0_be', -0.25750345),
#  ('pos_0_IN', -0.24173169),
#  ('lemma_0_have', -0.22749604),
#  ('word_0_cavity', -0.22716077),
#  ('med_prefix_0_sever', -0.21181071),
#  ('pos_0_PRP$', -0.20205858),
#  ('med_prefix_0_failure', -0.19337183),
#  ('lemma_0_patient', -0.19161217),
#  ('pos_0_CD', -0.19047482),
#  ('lemma_0_she', -0.17501353)]
#
# filter 186
# ------ positive features
# [('med_prefix_-2_posturing', 2.1673e-06),
#  ('med_prefix_-2_icterus', 2.1063081e-06),
#  ('med_prefix_-2_impaction', 1.8456823e-06),
#  ('med_prefix_0_malalignment', 1.7670654e-06),
#  ('med_prefix_0_other', 1.7384301e-06),
#  ('med_prefix_-2_withdrawal', 1.7358284e-06),
#  ('pos_-2_-RRB-', 1.6512654e-06),
#  ('med_prefix_0_symptoms', 1.5854587e-06),
#  ('med_prefix_-2_arrythmia', 1.5357175e-06),
#  ('pos_0_WDT', 1.5183373e-06)]
# ------ negative features
# [('pos_0_-RRB-', -1.910179e-06),
#  ('pos_-2_:', -1.6808857e-06),
#  ('med_prefix_-2_small', -1.6411732e-06),
#  ('med_prefix_0_posturing', -1.5475972e-06),
#  ('med_prefix_-2_still', -1.5199988e-06),
#  ('med_prefix_-2_aorti', -1.4970133e-06),
#  ('med_prefix_0_impaction', -1.4763004e-06),
#  ('med_prefix_0_presyncope', -1.4597648e-06),
#  ('word_length_-2_2', -1.4238176e-06),
#  ('word_pos_-2_6', -1.4073821e-06)]
#
# filter 187
# ------ positive features
# [('word_-1_valve', 0.00033431378),
#  ('word_-2_valve', 0.0003198724),
#  ('word_2_valve', 0.00031172382),
#  ('word_0_valve', 0.00030394114),
#  ('lemma_-1_valve', 0.0002955891),
#  ('word_1_valve', 0.00029501773),
#  ('lemma_-2_valve', 0.00028234199),
#  ('lemma_2_valve', 0.00027591767),
#  ('lemma_0_valve', 0.00026632086),
#  ('lemma_1_valve', 0.00025865479)]
# ------ negative features
# [('sentence_pos_-1_0', -0.00037968368),
#  ('sentence_pos_-2_0', -0.00036347972),
#  ('sentence_pos_2_0', -0.00035361436),
#  ('sentence_pos_0_0', -0.00034976652),
#  ('sentence_pos_1_0', -0.00033939746),
#  ('lemma_-1_normal', -0.00031641676),
#  ('lemma_-2_normal', -0.00030106574),
#  ('lemma_2_normal', -0.00029493551),
#  ('lemma_0_normal', -0.00028921818),
#  ('normal_-1_normal', -0.00028787457)]
#
# filter 188
# ------ positive features
# [('med_prefix_1_passa', 8.9080204e-05),
#  ('med_prefix_1_impaction', 8.4190739e-05),
#  ('sentence_length_1_0', 6.3188891e-05),
#  ('pos_0_-RRB-', 6.1646868e-05),
#  ('med_prefix_1_presyncope', 5.8426169e-05),
#  ('med_prefix_1_cardia', 5.6449586e-05),
#  ('pos_0_VBG', 5.5703178e-05),
#  ('word_pos_1_2', 5.5413875e-05),
#  ('med_prefix_1_sluggish', 5.2308384e-05),
#  ('med_prefix_1_posturing', 5.173976e-05)]
# ------ negative features
# [('med_prefix_1_other', -7.597026e-05),
#  ('pos_1_NNP', -6.4210741e-05),
#  ('pos_1_VBD', -5.7339716e-05),
#  ('med_prefix_1_malalignment', -5.5055971e-05),
#  ('med_prefix_1_duodenum', -5.3888682e-05),
#  ('med_prefix_1_thrombi', -5.151868e-05),
#  ('pos_1_NN', -5.1416639e-05),
#  ('word_pos_1_6', -4.9679547e-05),
#  ('word_length_1_4', -4.8889549e-05),
#  ('umls_match_tag_prefix_0_I', -4.8437818e-05)]
#
# filter 189
# ------ positive features
# [('word_0_cavity', 0.38184601),
#  ('lemma_0_have', 0.37981412),
#  ('med_prefix_0_sever', 0.37543124),
#  ('word_length_0_0', 0.37322563),
#  ('lemma_0_be', 0.34603333),
#  ('lemma_0_patient', 0.32189754),
#  ('word_length_0_5', 0.32010931),
#  ('med_prefix_0_failure', 0.31755003),
#  ('lemma_0_she', 0.31555647),
#  ('lemma_0_ivc', 0.28687611)]
# ------ negative features
# [('lemma_0_fever', -0.41158363),
#  ('normal_0_afib', -0.38701442),
#  ('lemma_0_fall', -0.34580809),
#  ('prefix_0_SOB', -0.34551245),
#  ('med_prefix_0_calci', -0.3435024),
#  ('suffix_0_GIB', -0.32988742),
#  ('prefix_0_dys', -0.32745764),
#  ('lemma_0_mass', -0.32036993),
#  ('prefix_0_ARD', -0.30704889),
#  ('lemma_0_lesion', -0.30422428)]
#
# filter 190
# ------ positive features
# [('pos_-2_JJ', 0.14816795),
#  ('pos_0_CC', 0.14120039),
#  ('pos_2_NN', 0.13083979),
#  ('lemma_0_be', 0.11453206),
#  ('umls_match_tag_full_2_I', 0.096164845),
#  ('word_length_0_0', 0.093645304),
#  ('capitalized_-2_1', 0.09157899),
#  ('pos_-1_NNS', 0.081558824),
#  ('normal_0_and', 0.076492243),
#  ('pos_-1_IN', 0.076273493)]
# ------ negative features
# [('word_length_-2_3', -0.10146052),
#  ('pos_2_CC', -0.083890095),
#  ('lemma_-2_be', -0.078425787),
#  ('lemma_-1_be', -0.078328654),
#  ('pos_2_VBN', -0.073722556),
#  ('umls_match_tag_full_2_O', -0.072991461),
#  ('pos_-2_NN', -0.066776872),
#  ('lemma_-1_right', -0.064419702),
#  ('med_prefix_2__', -0.064121716),
#  ('word_length_2_0', -0.063916653)]
#
# filter 191
# ------ positive features
# [('med_prefix_-1_presyncope', 0.00062630692),
#  ('word_pos_-2_4', 0.00056473032),
#  ('med_prefix_-2_presyncope', 0.00051851047),
#  ('word_pos_-2_5', 0.00051265105),
#  ('med_prefix_-1_posturing', 0.00050751818),
#  ('pos_-1_CC', 0.0004803715),
#  ('word_length_-2_3', 0.00046169225),
#  ('med_prefix_-1_obesity', 0.00045829461),
#  ('pos_-2_VBN', 0.00045622175),
#  ('med_prefix_-2_obesity', 0.00045410695)]
# ------ negative features
# [('sentence_length_-2_2', -0.00058613194),
#  ('med_prefix_-1_malalignment', -0.00054613646),
#  ('sentence_length_2_2', -0.00053385535),
#  ('pos_-2_DT', -0.00051987742),
#  ('sentence_length_-1_2', -0.00048542031),
#  ('umls_match_tag_prefix_-1_I', -0.00046441716),
#  ('med_prefix_-1_bleeding', -0.00045373879),
#  ('umls_match_tag_prefix_-2_I', -0.00041439652),
#  ('sentence_pos_1_4', -0.00041244007),
#  ('med_prefix_-2_malalignment', -0.00041065732)]
#
# filter 192
# ------ positive features
# [('umls_match_tag_full_0_O', 0.10153769),
#  ('pos_0_CC', 0.086943418),
#  ('word_length_-1_3', 0.081043854),
#  ('capitalized_2_0', 0.076257676),
#  ('word_length_0_0', 0.07510747),
#  ('pos_1_DT', 0.070501834),
#  ('pos_2_JJ', 0.059795637),
#  ('pos_1_JJ', 0.059297714),
#  ('umls_match_tag_full_2_I', 0.054817911),
#  ('sentence_pos_-1_0', 0.053503968)]
# ------ negative features
# [('pos_1_CC', -0.11122451),
#  ('umls_match_tag_full_0_B', -0.1110447),
#  ('suffix_0_nds', -0.074368313),
#  ('pos_-2_IN', -0.073250353),
#  ('umls_match_tag_full_0_I', -0.073105767),
#  ('suffix_0_lic', -0.070514202),
#  ('pos_0_NNS', -0.061008032),
#  ('word_0_function', -0.060004219),
#  ('lemma_0_function', -0.058366615),
#  ('capitalized_0_0', -0.05608207)]
#
# filter 193
# ------ positive features
# [('pos_-1_CC', 3.9464387e-11),
#  ('suffix_-1_tic', 2.8429923e-11),
#  ('normal_-1_and', 2.2005738e-11),
#  ('suffix_-1_and', 1.964922e-11),
#  ('prefix_-1_and', 1.9431401e-11),
#  ('word_length_-1_0', 1.9366203e-11),
#  ('lemma_-1_and', 1.7843336e-11),
#  ('word_-1_and', 1.7703441e-11),
#  ('word_length_-1_1', 1.5077569e-11),
#  ('lemma_-1_,', 1.4971979e-11)]
# ------ negative features
# [('lemma_-1_decrease', -1.9088602e-11),
#  ('suffix_-1_ted', -1.8306153e-11),
#  ('suffix_-1_ine', -1.753005e-11),
#  ('lemma_-1_elevated', -1.6359081e-11),
#  ('prefix_-1_res', -1.5388643e-11),
#  ('pos_-1_VBN', -1.5175855e-11),
#  ('pos_-1_NN', -1.5148988e-11),
#  ('word_-1_dilated', -1.3497498e-11),
#  ('word_-1_leaflets', -1.3112509e-11),
#  ('suffix_-1_ral', -1.1366753e-11)]
#
# filter 194
# ------ positive features
# [('med_prefix_-2_presyncope', 0.00055074884),
#  ('med_prefix_-2_posturing', 0.00051319104),
#  ('pos_-2_-RRB-', 0.00049653708),
#  ('med_prefix_-2_obesity', 0.00047831942),
#  ('med_prefix_-2_diaphore', 0.00046255966),
#  ('pos_-2_VBG', 0.00044073901),
#  ('word_pos_-2_4', 0.00043250702),
#  ('pos_-2_PRP', 0.00042651448),
#  ('pos_-2_VBN', 0.00041865435),
#  ('med_prefix_-2_syncop', 0.00040744091)]
# ------ negative features
# [('med_prefix_-2_malalignment', -0.00050987565),
#  ('umls_match_tag_prefix_-2_I', -0.0004740766),
#  ('med_prefix_-2_constipation', -0.00042335902),
#  ('sentence_length_-2_2', -0.00042090783),
#  ('med_prefix_-2_bleeding', -0.00040499395),
#  ('med_prefix_-2_other', -0.00038217611),
#  ('med_prefix_-2_fracture', -0.00037979661),
#  ('med_prefix_-2_hypertrophy', -0.00037146435),
#  ('med_prefix_-2_cervic', -0.00034366018),
#  ('med_prefix_1_malalignment', -0.00033614403)]
#
# filter 195
# ------ positive features
# [('med_prefix_-2_strong', 1.396638e-06),
#  ('med_prefix_-2_fluid', 1.3166376e-06),
#  ('med_prefix_-2_other', 1.0873124e-06),
#  ('med_prefix_1_aorti', 1.0782716e-06),
#  ('sentence_length_-2_2', 1.0734925e-06),
#  ('pos_-2_VBD', 1.0520898e-06),
#  ('med_prefix_1_other', 1.0506386e-06),
#  ('med_prefix_1_symptoms', 1.0092202e-06),
#  ('pos_1_FW', 9.9724764e-07),
#  ('med_prefix_1_malalignment', 9.9520503e-07)]
# ------ negative features
# [('med_prefix_-2_impaction', -1.7031836e-06),
#  ('med_prefix_-2_posturing', -1.6842646e-06),
#  ('med_prefix_-2_bradycardi', -1.3715127e-06),
#  ('pos_-2_VB', -1.1969753e-06),
#  ('med_prefix_-2_obesity', -1.1417691e-06),
#  ('pos_-2_RB', -1.0857941e-06),
#  ('med_prefix_-2_ventricul', -9.8574674e-07),
#  ('word_pos_-2_6', -9.5980579e-07),
#  ('med_prefix_1_impaction', -9.1931116e-07),
#  ('med_prefix_-2_syncop', -9.1794777e-07)]
#
# filter 196
# ------ positive features
# [('pos_0_NN', 0.20609935),
#  ('pos_-1_CD', 0.20248795),
#  ('word_length_-1_2', 0.19989714),
#  ('lemma_-1_be', 0.1909883),
#  ('word_length_-1_4', 0.17082228),
#  ('pos_1_NN', 0.16224344),
#  ('pos_-1_JJ', 0.16153985),
#  ('capitalized_0_0', 0.15450335),
#  ('word_length_-1_0', 0.1462718),
#  ('umls_match_tag_full_0_I', 0.14451857)]
# ------ negative features
# [('lemma_-1_fever', -0.14128782),
#  ('normal_-1_afib', -0.12323383),
#  ('lemma_-1_fall', -0.12114727),
#  ('lemma_1_decrease', -0.1103138),
#  ('prefix_-1_SOB', -0.10993148),
#  ('suffix_-1_GIB', -0.10622321),
#  ('prefix_-1_dys', -0.10486213),
#  ('umls_match_tag_acro_-1_I ', -0.10438225),
#  ('pos_-1_,', -0.10252405),
#  ('normal_-1_htn', -0.10210476)]
#
# filter 197
# ------ positive features
# [('pos_-1_VBG', 0.0010057995),
#  ('med_prefix_0_fluid', 0.00090815133),
#  ('med_prefix_-1_still', 0.0008668814),
#  ('pos_-1_-RRB-', 0.0008496113),
#  ('med_prefix_-1_diaphore', 0.00084075396),
#  ('pos_-1_VBN', 0.00080942333),
#  ('med_prefix_-1_impaction', 0.00080577791),
#  ('med_prefix_-1_posturing', 0.00077831862),
#  ('word_pos_-1_5', 0.00076615391),
#  ('med_prefix_0_still', 0.00073590258)]
# ------ negative features
# [('med_prefix_-1_malalignment', -0.0012941277),
#  ('med_prefix_0_malalignment', -0.0011170235),
#  ('med_prefix_-1_other', -0.0009333014),
#  ('med_prefix_-1_fracture', -0.00087478716),
#  ('med_prefix_-1_aorti', -0.00084266416),
#  ('med_prefix_-1_symptoms', -0.0008258163),
#  ('med_prefix_1_malalignment', -0.00080784241),
#  ('med_prefix_-1_hypertrophy', -0.00077101344),
#  ('med_prefix_0_ventricul', -0.00070476573),
#  ('pos_-1_DT', -0.00068125897)]
#
# filter 198
# ------ positive features
# [('pos_-2_IN', 0.027718145),
#  ('umls_match_tag_full_-1_B', 0.023265349),
#  ('sentence_length_-2_1', 0.022101467),
#  ('word_0_valve', 0.021561926),
#  ('lemma_0_valve', 0.020558365),
#  ('word_length_-2_0', 0.020058332),
#  ('sentence_length_-1_1', 0.019501176),
#  ('word_pos_-2_5', 0.018430596),
#  ('pos_2_IN', 0.018113256),
#  ('sentence_length_1_1', 0.017464289)]
# ------ negative features
# [
# ('word_length_1_4', -0.033750597),
#  ('word_length_-2_4', -0.033257533),
#  ('pos_1_NN', -0.031807318),
#  ('word_length_-1_4', -0.02494674),
#  ('sentence_pos_0_0', -0.02484693),
#  ('pos_-1_NNS', -0.02336489),
#  ('word_length_2_4', -0.022217864),
#  ('word_length_2_5', -0.022158841),
#  ('pos_2_CC', -0.019960716),
#  ('pos_-2_NNS', -0.019822536)]
#
# filter 199
# ------ positive features
# [('pos_0_NN', 0.15132748),
#  ('lemma_-1_be', 0.15099859),
#  ('word_length_-1_3', 0.14818633),
#  ('word_length_-1_4', 0.14122857),
#  ('pos_-1_CD', 0.14058638),
#  ('umls_match_tag_full_0_I', 0.14032811),
#  ('pos_0_NNS', 0.13288803),
#  ('capitalized_0_0', 0.12260254),
#  ('pos_-1_JJ', 0.1171997),
#  ('word_length_1_3', 0.10493115)]
# ------ negative features
# [('pos_0_CC', -0.16955189),
#  ('lemma_0_or', -0.11409235),
#  ('pos_-1_CC', -0.10983538),
#  ('pos_-2_JJ', -0.10396109),
#  ('pos_2_NN', -0.093455911),
#  ('word_0_or', -0.092212804),
#  ('lemma_-1_fever', -0.091236129),
#  ('normal_-1_afib', -0.083412766),
#  ('med_prefix_-1__', -0.080284379),
#  ('lemma_0_r', -0.079720527)]
